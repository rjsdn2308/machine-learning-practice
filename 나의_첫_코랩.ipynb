# %% [markdown]
# <a href="https://colab.research.google.com/github/rjsdn2308/machine-learning-practice/blob/main/%EB%82%98%EC%9D%98_%EC%B2%AB_%EC%BD%94%EB%9E%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world!')
# Out:
# hello world!

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.18.0'

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive')
